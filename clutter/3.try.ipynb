# %%
from pyoc import OpenCalphad
oc = OpenCalphad(oc_executable='/usr/local/bin/OC')
print(oc.version())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from pyoc import OpenCalphad
#       2 oc = OpenCalphad(oc_executable='/usr/local/bin/OC')
#       3 print(oc.version())
#
# ImportError: cannot import name 'OpenCalphad' from 'pyoc' (/run/media/adi/New Volume/conda-envs/struct/lib/python3.11/site-packages/pyoc/__init__.py)
